# %% [markdown]
# # Aula 07 - PDFs protegidos por senha e Otimização
#
# Alguns PDFs (como boletos ou exames) vêm com senha para abrir. A biblioteca `pdf2image` sabe como lidar com eles. Além disso, vamos aprender a deixar o código mais RÁPIDO.
#
# Imagine que converter 100 páginas de um PDF é como traduzir 100 páginas de um livro. Se você tem 1 tradutor, demora muito. Se você chama 4 tradutores simultâneos, o tempo cai drasticamente. Isso é o que chamamos de **Threads** (Linhas de execução paralelas).

# %%
from pdf2image import convert_from_path
# O código abaixo está comentado pois você precisaria de um pdf com senha local real.

# %% [markdown]
# ## 1. Lidando com Senhas (userpw)

# %%
# Se o arquivo tiver senha, e você rodar o convert_from_path normal, o código trava e dá erro.
# A solução é passar o argumento 'userpw' (User Password).

# imagens = convert_from_path('boleto_secreto.pdf', userpw='123456')
# print('PDF com senha aberto e convertido!')

# %% [markdown]
# ## 2. Otimizando Velocidade (thread_count)

# %%
# Digamos que você tem um e-book gigante de 300 páginas em PDF.
# O parâmetro 'thread_count=4' diz para o Python alocar 4 núcleos do seu processador
# para transformar várias imagens ao mesmo tempo. É MUITO mais rápido!

# imagens_rapidas = convert_from_path('livro_gigante.pdf', thread_count=4)
# print('Imagens geradas rapidamente em paralelo!')
